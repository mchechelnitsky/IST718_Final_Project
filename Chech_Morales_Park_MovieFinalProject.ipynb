# %%
import pandas as pd

# %%
#base data set
base_data = pd.read_csv("base_data.csv")
#cleaning step 1: drop unnecessary columns
base_data = base_data.drop(['belongs_to_collection','homepage','poster_path','original_title','crew'], axis=1)
base_data = base_data.set_index('id')
#shuffle title to lead column
names = base_data['title']
base_data = base_data.drop(['title'],axis=1)
base_data.insert(0,'Title',names)
base_data['Title'] = base_data['Title'].str.lower()
base_data.shape
# Out:
# (3000, 17)

# %%
imdb_df = pd.read_csv("imdb.csv")
imdb_df = imdb_df.drop(['Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47'],axis=1)
#imdb_df.head()
# Out:
# Index(['fn', 'tid', 'title', 'wordsInTitle', 'url', 'imdbRating',
#        'ratingCount', 'duration', 'year', 'type', 'nrOfWins',
#        'nrOfNominations', 'nrOfPhotos', 'nrOfNewsArticles', 'nrOfUserReviews',
#        'nrOfGenre', 'Action', 'Adult', 'Adventure', 'Animation', 'Biography',
#        'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy',
#        'FilmNoir', 'GameShow', 'History', 'Horror', 'Music', 'Musical',
#        'Mystery', 'News', 'RealityTV', 'Romance', 'SciFi', 'Short', 'Sport',
#        'TalkShow', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
data = base_data.join(imdb_df.set_index('wordsInTitle'),on='Title',how='inner')
data = data.dropna()
print(data.shape)
data.head()
# Out:
# (469, 60)
#               Title     budget  \
# id
# 10    a mighty wind    6000000
# 11            rocky    1000000
# 13  american beauty   15000000
# 15  minority report  102000000
# 21    lost in space   80000000
#
#                                                genres    imdb_id  \
# id
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...  tt0310281
# 11                      [{'id': 18, 'name': 'Drama'}]  tt0075148
# 13                      [{'id': 18, 'name': 'Drama'}]  tt0169547
# 15  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt0181689
# 21  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...  tt0120738
#
#    original_language                                           overview  \
# id
# 10                en  In "A Mighty Wind", director Christopher Guest...
# 11                en  When world heavyweight boxing champion, Apollo...
# 13                en  Lester Burnham, a depressed suburban father in...
# ...
